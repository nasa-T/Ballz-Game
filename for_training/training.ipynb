# %%
import gymnasium as gym
import numpy as np
from ai_trainer import *
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1790399464.201854  180420 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1790399464.202107  180420 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1790399464.227675  180420 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1790399464.928500  180420 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1790399464.928661  180420 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
gym.register("gymnasium_env/Ballz-v0", entry_point=BallzEnv, max_episode_steps=100)

# %%
env = gym.make("gymnasium_env/Ballz-v0", width=700, height=950, nblocks=7, render_mode="human")

# %%
env.observation_space
# Out:
# Dict('blocks': Box(0, 10000, (10, 7, 2), int64), 'nballs': Box(0, 10000, (), int64), 'position': Box(0, 700, (), int64))

# %%
from gymnasium.utils.env_checker import check_env

# %%
check_env(env.unwrapped)
print("Environment passes all checks!")
# Out:
# /home/Tasan/Coding/ballz/gameVenv/lib/python3.12/site-packages/gymnasium/spaces/box.py:415: UserWarning: WARN: Casting input x to numpy array.
#   gym.logger.warn("Casting input x to numpy array.")
# /home/Tasan/Coding/ballz/gameVenv/lib/python3.12/site-packages/gymnasium/spaces/box.py:415: UserWarning: WARN: Casting input x to numpy array.
#   gym.logger.warn("Casting input x to numpy array.")
# Environment passes all checks!

# %%
agent = BallzAgent(env)
# Out:
# E0000 00:00:1790399469.002800  180420 cuda_executor.cc:1737] INTERNAL: CUDA Runtime error: Failed call to cudaGetRuntimeVersion: Error loading CUDA libraries. GPU will not be used.: Error loading CUDA libraries. GPU will not be used.
# W0000 00:00:1790399469.025507  180420 gpu_device.cc:2365] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
obs1, _ = env.reset()

# %%
state = agent.forward(obs1)

# %%
rewards = agent.train(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 rewards = agent.train(10)
#
# File ~/Coding/ballz/for_training/ai_trainer.py:181, in BallzAgent.train(self, n_episodes)
#     179 for _ in range(n_episodes):
#     180     state, info = self.env.reset()
# --> 181     episode_reward, new_state = self.run_episode(state)
#     182     rewards.append(episode_reward)
#     184 return rewards
#
# File ~/Coding/ballz/for_training/ai_trainer.py:195, in BallzAgent.run_episode(self, state)
#     193 a_mean, a_std = self.actor(state_tensor)[0]
#     194 action = np.clip(np.random.normal(a_mean, np.abs(a_std)), a_min=-0.9, a_max=0.9) # sample from gaussian
# --> 195 observation, reward, terminated, _, info = self.env.step(action)
#     196 new_state_tensor = self.forward(observation) # observation as a tensor
#     198 curr_val = self.critic(state_tensor)[0][0]
#
# File ~/Coding/ballz/gameVenv/lib/python3.12/site-packages/gymnasium/wrappers/common.py:124, in TimeLimit.step(self, action)
#     111 def step(
#     112     self, action: ActType
#     113 ) -> tuple[ObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     114     """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#     115
#     116     Args:
#    (...)    122
#     123     """
# --> 124     observation, reward, terminated, truncated, info = self.env.step(action)
#     125     self._elapsed_steps += 1
#     127     if self._elapsed_steps >= self._max_episode_steps:
#
# File ~/Coding/ballz/gameVenv/lib/python3.12/site-packages/gymnasium/wrappers/common.py:392, in OrderEnforcing.step(self, action)
#     390 if not self._has_reset:
#     391     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# --> 392 return super().step(action)
#
# File ~/Coding/ballz/gameVenv/lib/python3.12/site-packages/gymnasium/core.py:327, in Wrapper.step(self, action)
#     323 def step(
#     324     self, action: WrapperActType
#     325 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     326     """Uses the :meth:`step` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 327     return self.env.step(action)
#
# File ~/Coding/ballz/gameVenv/lib/python3.12/site-packages/gymnasium/wrappers/common.py:284, in PassiveEnvChecker.step(self, action)
#     282     return env_step_passive_checker(self.env, action)
#     283 else:
# --> 284     return self.env.step(action)
#
# File ~/Coding/ballz/for_training/ai_trainer.py:89, in BallzEnv.step(self, action)
#      86 game_over = self.game.step(np.pi/2*action, render=render)
#      87 observation = self._get_obs()
# ---> 89 reward = 1 if not game_over else -self.limit
#      91 terminated = (self.game.index >= 1000) or game_over
#      92 info = self._get_info()
#
# AttributeError: 'BallzEnv' object has no attribute 'limit'

# %%
rewards

# %%
rewards2 = agent.train(10)

# %%
rewards2
